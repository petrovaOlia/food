# %%
import pandas as pd
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot as plt
global off_df
plt.close('all')

# %%
off_df = pd.read_csv('C:/Users/XE/en.openfoodfacts.org.products.tsv', sep='\t', low_memory=False, decimal=".")

# %%
def no_null_objects(data, columns=None):
    if columns is None:
        columns = data.columns
    return data[np.logical_not(np.any(data[columns].isnull().values, axis=1))]

no_null_objects(off_df[["product_name", "ingredients_from_palm_oil_n"]].sort_values(by=['ingredients_from_palm_oil_n']))
# Out:
#                                              product_name  \
# 1                          Banana Chips Sweetened (Whole)
# 200871                                       Jus de pomme
# 200872                              Le Fruit - Multifruit
# 200873                                    Le Fruit Ananas
# 200874                              Le Fruit Pamplemousse
# 200875                                 Jus d'orange Joker
# 200876                  Le Pur Jus 100% Orange avec Pulpe
# 200877                                         Le Pur Jus
# 200878                                Le Pur Jus d'Ananas
# 200879                                         Multifruit
# 200880        Le Pur Jus Pamplemousse Rose et Blanc Joker
# 200881                                         Le Pur Jus
# 200882                     Le Pur Jus multifruit exotique
# 200883               Pur jus de fruit d'orange sans pulpe
# 200885                                 Le Fruit Cranberry
# ...

# %%
list(off_df)
# Out:
# ['code',
#  'url',
#  'creator',
#  'created_t',
#  'created_datetime',
#  'last_modified_t',
#  'last_modified_datetime',
#  'product_name',
#  'generic_name',
#  'quantity',
#  'packaging',
#  'packaging_tags',
#  'brands',
#  'brands_tags',
#  'categories',
#  'categories_tags',
#  'categories_en',
#  'origins',
#  'origins_tags',
#  'manufacturing_places',
#  'manufacturing_places_tags',
#  'labels',
#  'labels_tags',
#  'labels_en',
#  'emb_codes',
#  'emb_codes_tags',
#  'first_packaging_code_geo',
#  'cities',
#  'cities_tags',
#  'purchase_places',
#  'stores',
#  'countries',
#  'countries_tags',
#  'countries_en',
#  'ingredients_text',
#  'allergens',
#  'allergens_en',
#  'traces',
#  'traces_tags',
#  'traces_en',
#  'serving_size',
#  'no_nutriments',
#  'additives_n',
#  'additives',
#  'additives_tags',
#  'additives_en',
#  'ingredients_from_palm_oil_n',
#  'ingredients_from_palm_oil',
#  'ingredients_from_palm_oil_tags',
# ...

# %%
#countries = off_df["countries_en"].value_counts()
#off_df[["countries_en", "ingredients_from_palm_oil_n"]][:20].groupby("countries_en").mean().plot.barh()

df = no_null_objects(off_df[["countries_en", "ingredients_from_palm_oil_n", "ingredients_that_may_be_from_palm_oil_n"]])
df[df["countries_en"].isin(countries[:20].index)].groupby("countries_en").mean().plot.barh()

# %%
vegans = off_df.loc[(off_df['main_category'] == 'en:plant-based-foods-and-beverages')]
#no_null_objects(vegans[["product_name", "calcium_100g", "omega-3-fat_100g", "iron_100g"]])
no_null_objects(vegans[["product_name", "omega-3-fat_100g"]])
# Out:
#                                              product_name  omega-3-fat_100g
# 67355                                           margarine             4.000
# 67426                           Vegetarian Chicken Breast             0.427
# 68862                    Pain 12 grains moulus (avec lin)             1.000
# 131787                                   Chia-Samen Natur            18.000
# 157750                             Fish-Free Golden Filet             0.208
# 181861                             White seeded farmhouse             1.740
# 182520                             Tartine & Cuisson Doux             5.500
# 182547                                      Huile de noix            12.000
# 187455                                   Aceite de linaza            52.000
# 188414            Filet de Harengs - Butella au Tournesol             1.800
# 188431                        Margarine allégée tournesol             1.800
# ...

# %%
vegans = off_df.loc[(off_df['main_category'] == 'en:plant-based-foods-and-beverages')]
#vegans = vegans[['quantity']].fillna('0')
#vegans = vegans[['calcium_100g']].fillna('0')
vegans = vegans[vegans['quantity'].str.contains(' g')]
vegans = vegans['quantity'].str.split(' g').str[0].str.split(' ').str[-1]
vegans = vegans['quantity'].str.split(' ').str[-1]
vegans = vegans.str.replace('(', '')
vegans = vegans['quantity'].str.replace(',', '.')
vegans = pd.to_numeric(vegans['quantity'], errors='coerce')
vegans['all_calcium'] = vegans['calcium_100g']*vegans['quantity']/100
vegans
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-fd2066eaf16a> in <module>
#       2 #vegans = vegans[['quantity']].fillna('0')
#       3 #vegans = vegans[['calcium_100g']].fillna('0')
# ----> 4 vegans = vegans[vegans['quantity'].str.contains(' g')]
#       5 vegans = vegans['quantity'].str.split(' g').str[0].str.split(' ').str[-1]
#       6 vegans = vegans['quantity'].str.split(' ').str[-1]
#
# c:\users\xe\envs\labs\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ...

# %%
off_df.columns = off_df.columns.str.replace('-','_')
serv_size = off_df.loc[(off_df['main_category'] == 'en:plant-based-foods-and-beverages')]
serv_size = no_null_objects(serv_size[["product_name", "omega_3_fat_100g", "omega_6_fat_100g", "serving_size"]])
serv_size = serv_size.loc[serv_size["serving_size"].str.contains(' g')]
serv_size.serving_size = serv_size["serving_size"].str.split(' g').str[0]
serv_size.serving_size = serv_size["serving_size"].str.split(' ').str[-1]
serv_size.serving_size = serv_size["serving_size"].str.replace('(', '')
serv_size.serving_size = serv_size["serving_size"].str.replace(',', '.')
serv_size.serving_size = pd.to_numeric(serv_size["serving_size"], errors='coerce')
serv_size.omega_3_fat_100g = pd.to_numeric(serv_size["omega_3_fat_100g"], errors='coerce')
serv_size['all_omega3'] = serv_size.omega_3_fat_100g * serv_size.serving_size/100
serv_size.omega_6_fat_100g = pd.to_numeric(serv_size["omega_6_fat_100g"], errors='coerce')
serv_size['all_omega6'] = serv_size.omega_6_fat_100g * serv_size.serving_size/100
serv_size.sort_values(by=['all_omega3', 'all_omega6'], ascending=False)
ax = serv_size[["product_name", 'all_omega3', 'all_omega6']][:20].plot.barh(x='product_name')
#serv_size[:20].plot(kind='bar',x='product_name',y='all_omega3')
ax.axvline(x=0.8)
ax.axvline(x=4.5, color='orange')

# %%
df = no_null_objects(off_df[["countries_en", "potassium_100g"]])
df.potassium_100g = pd.to_numeric(df["potassium_100g"], errors='coerce')
serv_size =df.loc[(df["potassium_100g"] < 0.2)]
pp = serv_size["countries_en"].value_counts()
pp
# Out:
# United States                                                  13677
# France                                                           145
# Germany                                                           40
# Australia                                                         20
# France,United States                                              19
# Russia                                                            10
# Sweden                                                            10
# Canada                                                            10
# United Kingdom                                                     7
# Spain                                                              7
# Portugal                                                           5
# New Zealand                                                        4
# France,Switzerland                                                 4
# Belgium                                                            4
# ...
